# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

html = urlopen('https://news.google.com/topics/CAAqJQgKIh9DQkFTRVFvSUwyMHZNR3QwTlRFU0JYcG9MVlJYS0FBUAE?hl=zh-TW&gl=TW&ceid=TW%3Azh-Hant')
bsObj = BeautifulSoup(html.read(), 'html.parser')
bsObj.article
# Out:
# <article class="MQsxIb xTewfe R7GTQ keNKEd j7vNaf Cc0Z5d EjqUne" data-kind="13" data-n-cvid="i5" data-n-et="107" data-n-ham="true" data-n-vlb="0" jsaction=";rcuQ6b:npT2md; click:KjsqPd;EXlHgb:HQ4Dqd" jscontroller="mhFxVb" jsdata="oM6qxc;CBMiJWh0dHBzOi8vd3d3LnN0b3JtLm1nL2xpZmVzdHlsZS8yNjI3NjPSASZodHRwczovL3d3dy5zdG9ybS5tZy9hbXBhcnRpY2xlLzI2Mjc2Mw;7" jsmodel="QWGJif zT6vwb"><a aria-hidden="true" class="VDXfz" href="./articles/CBMiJWh0dHBzOi8vd3d3LnN0b3JtLm1nL2xpZmVzdHlsZS8yNjI3NjPSASZodHRwczovL3d3dy5zdG9ybS5tZy9hbXBhcnRpY2xlLzI2Mjc2Mw?hl=zh-TW&amp;gl=TW&amp;ceid=TW%3Azh-Hant" tabindex="-1" target="_blank"></a><h3 class="ipQwMb ekueJc RD0gLb"><a class="DY5T1d" href="./articles/CBMiJWh0dHBzOi8vd3d3LnN0b3JtLm1nL2xpZmVzdHlsZS8yNjI3NjPSASZodHRwczovL3d3dy5zdG9ybS5tZy9hbXBhcnRpY2xlLzI2Mjc2Mw?hl=zh-TW&amp;gl=TW&amp;ceid=TW%3Azh-Hant">為何血糖低、頭暈時，吃巧克力和麵包沒有用？醫師的救急建議，人人都該記下來！</a></h3><div aria-hidden="true" class="Da10Tb Rai5ob" jsname="jVqMGc"><span class="xBbh9">低血糖是糖尿病常見的症狀之一，輕忽恐有致命風險。醫師提醒，血糖太低，
# ...

# %%
bsObj.article.a
# Out:
# <a aria-hidden="true" class="VDXfz" href="./articles/CBMiJWh0dHBzOi8vd3d3LnN0b3JtLm1nL2xpZmVzdHlsZS8yNjI3NjPSASZodHRwczovL3d3dy5zdG9ybS5tZy9hbXBhcnRpY2xlLzI2Mjc2Mw?hl=zh-TW&amp;gl=TW&amp;ceid=TW%3Azh-Hant" tabindex="-1" target="_blank"></a>

# %%
titleList = bsObj.findAll("a", {"class": "DY5T1d"})
for title in titleList:
    print(title.get_text())
# Out:
# 為何血糖低、頭暈時，吃巧克力和麵包沒有用？醫師的救急建議，人人都該記下來！
# 不舉、憂鬱、沒精神，恐怕是「男性更年期」來報到？醫生：出現這8種症狀，趕快去檢查
# 幾乎所有失智症患者都有的8大前兆！醫生說的請記牢，符合2項就得小心了…
# 台灣的兒童竟然是亞洲最胖！專家提醒：小孩飲食觀念差，小心得這10種病
# 喝酒都不會臉紅的人，代表肝功能很好？醫生打臉：灌了好幾杯還「面不改色」才要小心！
# 染髮劑使用不當，可能出現紅斑、搔癢、水泡、潰爛…這4個撇步教你健康染髮！
# 年紀輕輕就得到高血壓，該怎麼辦？中醫師教你這樣調理身體…
# 洗牙真的能讓牙齒變白嗎？琺瑯質會不會越洗越薄？醫師破解常見迷思！
# 早期無任何症狀、發現時已經是大腸癌晚期…醫師：這2種人最好每年接受檢查
# 嫌榴槤臭不敢吃？其實它不但可以壯陽，還有這些豐富營養！不過這5個禁忌千萬要注意
# 小腿突然變粗不一定是胖，而是水腫！醫生教9招秘笈讓你輕鬆找回美腿
# 孩子成績退步、經常情緒低落…醫生：兒童也會罹患憂鬱症，最好「這樣」預防
# 便祕才不是多吃蔬果就能「嗯」出來！少了這個關鍵步驟，越吃只會積越多啊…
# 一餐吃十幾塊蘿蔔糕，血糖就意外飆高…營養師4大建議，吃東西真的要謹慎啊！
# 想舒緩全身痠痛，熱敷還是冰敷才有效？別猜了，運動醫學專家給出正確答案…
# 中壢輪胎廠大火恐釋毒，毒物專家建議，有這些症狀請儘快就醫！
# 突破一般人的痠痛迷思！復健科醫師：7成以上坐骨神經痛，不需要治療那條神經！
# 減肥絕對不能吃澱粉？營養師教你這樣挑澱粉食物，吃得又飽又減重！
# 很多癌症患者不是因病過世，是死於營養不良！北醫營養主任公開健康飲食關鍵…
# 原來性生活這麼重要！實驗證明提高記憶力、防阿茲海默症的6種方法，一定要學起來
# 別再羨慕別人了！讀讀莊子8則寓言，你擁有的一切，價值或許遠超出你想像…
# 新手爸媽該知道的「嬰兒搖晃症候群」…只要幾秒就可能對寶寶造成永久傷害！
# 別再說運動傷膝蓋了！想延長膝關節使用年限，醫師建議游泳、騎腳踏車有2點要改變
# 吃一顆粽子的熱量，要跑8公里才能消耗完！營養師提供健康粽食譜，這樣吃就對了
# 容易嘴破不只火氣大而已！台大醫師：反覆性口腔潰瘍可能造成9種疾病
# 罹患高血壓，就只能吃藥一輩子了嗎？他花了一年努力做這件事，竟然停藥了！
# ...

# %%
authorList = bsObj.findAll("a", {"class": "wEwyrc AVN2gc uQIVzc Sksgp"})
for author in authorList:
    print(author.get_text())
# Out:
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒
# 風傳媒

# %%
timeList = bsObj.findAll("time", {"class": "WW6dff uQIVzc Sksgp"})
for time in timeList:
    print(time.get_text())
# Out:
# 2018年8月7日
# 2018年9月11日
# 2018年6月15日

# %% [markdown]
# ### 一次擷取整個新聞相關資訊

# %%
articleList = bsObj.findAll("div", {"class": "NiLAwe y6IFtc R7GTQ keNKEd j7vNaf nID9nc"})
for article in articleList:
    print(article.div.article.h3.get_text())
    authorobj = article.div.article.div.find_next_siblings('div')
    print(authorobj[0].div.a.get_text())
    for publisher in authorobj:
        print(publisher.findAll("a", {"class": "wEwyrc AVN2gc uQIVzc Sksgp"}))
#         print(publisher.findAll("div")[0])
    print('---------------------------------')
# Out:
# 為何血糖低、頭暈時，吃巧克力和麵包沒有用？醫師的救急建議，人人都該記下來！
# 風傳媒
# [<a class="wEwyrc AVN2gc uQIVzc Sksgp">風傳媒</a>]
# ---------------------------------
# 不舉、憂鬱、沒精神，恐怕是「男性更年期」來報到？醫生：出現這8種症狀，趕快去檢查
# 風傳媒
# [<a class="wEwyrc AVN2gc uQIVzc Sksgp">風傳媒</a>]
# ---------------------------------
# 幾乎所有失智症患者都有的8大前兆！醫生說的請記牢，符合2項就得小心了…
# 風傳媒
# [<a class="wEwyrc AVN2gc uQIVzc Sksgp">風傳媒</a>]
# ---------------------------------
# 台灣的兒童竟然是亞洲最胖！專家提醒：小孩飲食觀念差，小心得這10種病
# 風傳媒
# [<a class="wEwyrc AVN2gc uQIVzc Sksgp">風傳媒</a>]
# ---------------------------------
# 喝酒都不會臉紅的人，代表肝功能很好？醫生打臉：灌了好幾杯還「面不改色」才要小心！
# 風傳媒
# [<a class="wEwyrc AVN2gc uQIVzc Sksgp">風傳媒</a>]
# ---------------------------------
# 染髮劑使用不當，可能出現紅斑、搔癢、水泡、潰爛…這4個撇步教你健康染髮！
# 風傳媒
# [<a class="wEwyrc AVN2gc uQIVzc Sksgp">風傳媒</a>]
# ---------------------------------
# 年紀輕輕就得到高血壓，該怎麼辦？中醫師教你這樣調理身體…
# 風傳媒
# [<a class="wEwyrc AVN2gc uQIVzc Sksgp">風傳媒</a>]
# ---------------------------------
# 洗牙真的能讓牙齒變白嗎？琺瑯質會不會越洗越薄？醫師破解常見迷思！
# 風傳媒
# ...
